# %%
students = []


def add_student():
    roll_no = input("Enter Roll Number: ")
    name = input("Enter Student Name: ")
    marks = float(input("Enter Marks: "))

    student = {
        "Roll No": roll_no,
        "Name": name,
        "Marks": marks
    }

    students.append(student)
    print("\nStudent Added Successfully!\n")


def display_students():
    if len(students) == 0:
        print("\nNo Student Records Found.\n")
        return

    print("\n===== Student Records =====")

    for student in students:
        print("--------------------------")
        print("Roll No :", student["Roll No"])
        print("Name    :", student["Name"])
        print("Marks   :", student["Marks"])
         
    print("--------------------------")


def search_student():
    roll_no = input("Enter Roll Number to Search: ")

    for student in students:
        if student["Roll No"] == roll_no:
            print("\nStudent Found")
            print("--------------------------")
            print("Roll No :", student["Roll No"])
            print("Name    :", student["Name"])
            print("Marks   :", student["Marks"])
            return

    print("\nStudent Not Found.")


def update_student():
    roll_no = input("Enter Roll Number to Update: ")

    for student in students:
        if student["Roll No"] == roll_no:
            student["Name"] = input("Enter New Name: ")
            student["Marks"] = float(input("Enter New Marks: "))

            print("\nStudent Updated Successfully!")
            return

    print("\nStudent Not Found.")


def delete_student():
    roll_no = input("Enter Roll Number to Delete: ")

    for student in students:
        if student["Roll No"] == roll_no:
            students.remove(student)
            print("\nStudent Deleted Successfully!")
            return

    print("\nStudent Not Found.")


def average_marks():
    if len(students) == 0:
        print("\nNo Student Records Found.")
        return

    total = 0

    for student in students:
        total += student["Marks"]

    average = total / len(students)

    print("\nAverage Marks =", average)


def highest_scorer():
    if len(students) == 0:
        print("\nNo Student Records Found.")
        return

    highest = students[0]

    for student in students:
        if student["Marks"] > highest["Marks"]:
            highest = student

    print("\nHighest Scorer")
    print("--------------------------")
    print("Roll No :", highest["Roll No"])
    print("Name    :", highest["Name"])
    print("Marks   :", highest["Marks"])


def lowest_scorer():
    if len(students) == 0:
        print("\nNo Student Records Found.")
        return

    lowest = students[0]

    for student in students:
        if student["Marks"] < lowest["Marks"]:
            lowest = student

    print("\nLowest Scorer")
    print("--------------------------")
    print("Roll No :", lowest["Roll No"])
    print("Name    :", lowest["Name"])
    print("Marks   :", lowest["Marks"])

while True:

    print("\n========== Student Record Management System ==========")
    print("1. Add Student")
    print("2. Display Students")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Delete Student")
    print("6. Average Marks")
    print("7. Highest Scorer")
    print("8. Lowest Scorer")
    print("9. Exit")

    choice = input("Enter Your Choice: ")

    if choice == "1":
        add_student()
        print("\nCurrent Records:")
        print(students)

    elif choice == "2":
        display_students()
        print("\nCurrent Records:")
        print(students)

    elif choice == "3":
        search_student()
        print("\nCurrent Records:")
        print(students)

    elif choice == "4":
        update_student()
        print("\nCurrent Records:")
        print(students)

    elif choice == "5":
        delete_student()
        print("\nCurrent Records:")
        print(students)

    elif choice == "6":
        average_marks()
        print("\nCurrent Records:")
        print(students)

    elif choice == "7":
        highest_scorer()
        print("\nCurrent Records:")
        print(students)

    elif choice == "8":
        lowest_scorer()
        print("\nCurrent Records:")
        print(students)

    elif choice == "9":
        print("\nThank You! Program Closed.")
        break

    else:
        print("\nInvalid Choice. Please Try Again.")
# Out:
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Student Added Successfully!
#
#
# Current Records:
# [{'Roll No': '101', 'Name': 'John', 'Marks': 87.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Student Added Successfully!
#
#
# Current Records:
# [{'Roll No': '101', 'Name': 'John', 'Marks': 87.0}, {'Roll No': '102', 'Name': 'Jeeva', 'Marks': 98.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Student Added Successfully!
#
#
# Current Records:
# [{'Roll No': '101', 'Name': 'John', 'Marks': 87.0}, {'Roll No': '102', 'Name': 'Jeeva', 'Marks': 98.0}, {'Roll No': '103', 'Name': 'Alex', 'Marks': 90.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# ===== Student Records =====
# --------------------------
# Roll No : 101
# Name    : John
# Marks   : 87.0
# --------------------------
# Roll No : 102
# Name    : Jeeva
# Marks   : 98.0
# --------------------------
# Roll No : 103
# Name    : Alex
# Marks   : 90.0
# --------------------------
#
# Current Records:
# [{'Roll No': '101', 'Name': 'John', 'Marks': 87.0}, {'Roll No': '102', 'Name': 'Jeeva', 'Marks': 98.0}, {'Roll No': '103', 'Name': 'Alex', 'Marks': 90.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Student Found
# --------------------------
# Roll No : 102
# Name    : Jeeva
# Marks   : 98.0
#
# Current Records:
# [{'Roll No': '101', 'Name': 'John', 'Marks': 87.0}, {'Roll No': '102', 'Name': 'Jeeva', 'Marks': 98.0}, {'Roll No': '103', 'Name': 'Alex', 'Marks': 90.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Student Updated Successfully!
#
# Current Records:
# [{'Roll No': '101', 'Name': 'Arun', 'Marks': 88.0}, {'Roll No': '102', 'Name': 'Jeeva', 'Marks': 98.0}, {'Roll No': '103', 'Name': 'Alex', 'Marks': 90.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Student Deleted Successfully!
#
# Current Records:
# [{'Roll No': '102', 'Name': 'Jeeva', 'Marks': 98.0}, {'Roll No': '103', 'Name': 'Alex', 'Marks': 90.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Average Marks = 94.0
#
# Current Records:
# [{'Roll No': '102', 'Name': 'Jeeva', 'Marks': 98.0}, {'Roll No': '103', 'Name': 'Alex', 'Marks': 90.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Highest Scorer
# --------------------------
# Roll No : 102
# Name    : Jeeva
# Marks   : 98.0
#
# Current Records:
# [{'Roll No': '102', 'Name': 'Jeeva', 'Marks': 98.0}, {'Roll No': '103', 'Name': 'Alex', 'Marks': 90.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Lowest Scorer
# --------------------------
# Roll No : 103
# Name    : Alex
# Marks   : 90.0
#
# Current Records:
# [{'Roll No': '102', 'Name': 'Jeeva', 'Marks': 98.0}, {'Roll No': '103', 'Name': 'Alex', 'Marks': 90.0}]
#
# ========== Student Record Management System ==========
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Average Marks
# 7. Highest Scorer
# 8. Lowest Scorer
# 9. Exit
#
# Thank You! Program Closed.
