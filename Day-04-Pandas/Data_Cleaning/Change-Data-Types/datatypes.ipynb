# %% [markdown]
# Read the CSV and Check Data Types

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Data_Cleaning\Change-Data-Types\Dataset\dirty_data_types.csv")

print("Dataset:")
print(df)

print("\nData Types:")
print(df.dtypes)
# Out:
# Dataset:
#    OrderID CustomerName  Age  Sales   OrderDate
# 0     1001         Arun   25  55000  2026-01-05
# 1     1002        Priya   24   1200  2026-01-08
# 2     1003        Rahul   28   2500  2026-01-12
# 3     1004        Divya   23  45000  2026-01-15
# 4     1005      Karthik   26  60000  2026-01-20
#
# Data Types:
# OrderID         int64
# CustomerName      str
# Age             int64
# Sales           int64
# OrderDate         str
# dtype: object

# %% [markdown]
# Change Data Type Using astype()

# %%
age_float = df["Age"].astype(float)

print(age_float.dtypes)
# Out:
# float64

# %% [markdown]
# Convert Date to Datetime

# %%
df_convert = pd.to_datetime(df["OrderDate"])

print(df_convert.dtypes)
# Out:
# datetime64[us]
