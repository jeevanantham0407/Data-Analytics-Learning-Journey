# %% [markdown]
# PROGRAM 1 - SELECTING ONE COLUMN

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df["Name"])
print("\n")
print(df["Marks"])
# Out:
# 0       Arun
# 1      Priya
# 2      Rahul
# 3      Divya
# 4    Karthik
# 5      Meena
# 6      Vijay
# 7     Anitha
# 8     Suresh
# 9    Lakshmi
# Name: Name, dtype: str
#
#
# 0    85
# 1    90
# 2    78
# 3    92
# 4    88
# 5    76
# 6    95
# 7    82
# 8    89
# 9    91
# Name: Marks, dtype: int64

# %% [markdown]
# PROGRAM 2 - SELECTING MULTIPLE COLUMNS

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print("SELECTING TWO COLUMNS:")
print(df[["Name", "Marks"]])
print("\nSELECTING THREE COLUMNS:")
print(df[["Name", "Age", "Marks"]])
# Out:
# SELECTING TWO COLUMNS:
#       Name  Marks
# 0     Arun     85
# 1    Priya     90
# 2    Rahul     78
# 3    Divya     92
# 4  Karthik     88
# 5    Meena     76
# 6    Vijay     95
# 7   Anitha     82
# 8   Suresh     89
# 9  Lakshmi     91
#
# SELECTING THREE COLUMNS:
#       Name  Age  Marks
# 0     Arun   21     85
# 1    Priya   22     90
# 2    Rahul   20     78
# 3    Divya   21     92
# 4  Karthik   22     88
# 5    Meena   20     76
# 6    Vijay   21     95
# 7   Anitha   22     82
# 8   Suresh   20     89
# 9  Lakshmi   21     91

# %% [markdown]
# PROGRAM 3 - SELECTING ROWS WITH ILOC

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print("FIRST ROW:")
print(df.iloc[0])
print("\nSECOND ROW:")
print(df.iloc[1])
# Out:
# FIRST ROW:
# StudentID      101
# Name          Arun
# Age             21
# Marks           85
# Department     CSE
# Name: 0, dtype: object
#
# SECOND ROW:
# StudentID       102
# Name          Priya
# Age              22
# Marks            90
# Department       IT
# Name: 1, dtype: object

# %% [markdown]
# PROGRAM 4 - SELECTING MULTIPLE ROWS BY ILOC

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print("SELECTING MULTIPLE ROWS:")
print(df.iloc[0:3])
# Out:
# SELECTING MULTIPLE ROWS:
#    StudentID   Name  Age  Marks Department
# 0        101   Arun   21     85        CSE
# 1        102  Priya   22     90         IT
# 2        103  Rahul   20     78        ECE

# %% [markdown]
# PROGRAM 5 - SELECTING SPECIFIC ROWS

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df.iloc[[0,2,4]])
# Out:
#    StudentID     Name  Age  Marks Department
# 0        101     Arun   21     85        CSE
# 2        103    Rahul   20     78        ECE
# 4        105  Karthik   22     88         IT

# %% [markdown]
# PROGRAM 6 - SELECTING ROWS AND COLUMNS USING ILOC

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df.iloc[0:2, [1,4]])
# Out:
#     Name Department
# 0   Arun        CSE
# 1  Priya         IT

# %% [markdown]
# PROGRAM 7 - SELECTION USING LABELS [ " LOC "]

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df.loc[1])
# Out:
# StudentID       102
# Name          Priya
# Age              22
# Marks            90
# Department       IT
# Name: 1, dtype: object

# %% [markdown]
# PROGRAM 8 - SELECTING A RANGE USING LOC

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df.loc[0:3, ["Name", "Marks"]])
# Out:
#     Name  Marks
# 0   Arun     85
# 1  Priya     90
# 2  Rahul     78
# 3  Divya     92

# %% [markdown]
# PROGRAM 9 - SELECTING A SINGLE CELL

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df)
print("\n")
print(df.loc[0, ["Marks"]])
print("\n")
print(df.loc[1, ["Age"]])
# Out:
#    StudentID     Name  Age  Marks Department
# 0        101     Arun   21     85        CSE
# 1        102    Priya   22     90         IT
# 2        103    Rahul   20     78        ECE
# 3        104    Divya   21     92        CSE
# 4        105  Karthik   22     88         IT
# 5        106    Meena   20     76        ECE
# 6        107    Vijay   21     95        CSE
# 7        108   Anitha   22     82         IT
# 8        109   Suresh   20     89        ECE
# 9        110  Lakshmi   21     91        CSE
#
#
# Marks    85
# Name: 0, dtype: int64
#
#
# Age    22
# Name: 1, dtype: int64
