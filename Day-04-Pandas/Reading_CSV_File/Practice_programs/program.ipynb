# %% [markdown]
# PROGRAM 1 - LOAD THE DATASET

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df)
# Out:
#    StudentID     Name  Age  Marks Department
# 0        101     Arun   21     85        CSE
# 1        102    Priya   22     90         IT
# 2        103    Rahul   20     78        ECE
# 3        104    Divya   21     92        CSE
# 4        105  Karthik   22     88         IT
# 5        106    Meena   20     76        ECE
# 6        107    Vijay   21     95        CSE
# 7        108   Anitha   22     82         IT
# 8        109   Suresh   20     89        ECE
# 9        110  Lakshmi   21     91        CSE

# %% [markdown]
# PROGRAM 2 - DATA INSPECTION

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df)
print("\nTOP ROWS:")
print(df.head())
print("\nBOTTOM ROWS:")
print(df.tail())
print("\nSHAPE:")
print(df.shape)
print("\nCOLUMNS:")
print(df.columns)
print("\nDATA TYPE:")
print(df.dtypes)
# Out:
#    StudentID     Name  Age  Marks Department
# 0        101     Arun   21     85        CSE
# 1        102    Priya   22     90         IT
# 2        103    Rahul   20     78        ECE
# 3        104    Divya   21     92        CSE
# 4        105  Karthik   22     88         IT
# 5        106    Meena   20     76        ECE
# 6        107    Vijay   21     95        CSE
# 7        108   Anitha   22     82         IT
# 8        109   Suresh   20     89        ECE
# 9        110  Lakshmi   21     91        CSE
#
# TOP ROWS:
#    StudentID     Name  Age  Marks Department
# 0        101     Arun   21     85        CSE
# 1        102    Priya   22     90         IT
# 2        103    Rahul   20     78        ECE
# 3        104    Divya   21     92        CSE
# 4        105  Karthik   22     88         IT
#
# BOTTOM ROWS:
#    StudentID     Name  Age  Marks Department
# 5        106    Meena   20     76        ECE
# 6        107    Vijay   21     95        CSE
# 7        108   Anitha   22     82         IT
# 8        109   Suresh   20     89        ECE
# 9        110  Lakshmi   21     91        CSE
#
# SHAPE:
# (10, 5)
#
# COLUMNS:
# Index(['StudentID', 'Name', 'Age', 'Marks', 'Department'], dtype='str')
#
# DATA TYPE:
# StudentID     int64
# Name            str
# Age           int64
# Marks         int64
# Department      str
# dtype: object

# %% [markdown]
# PROGRAM 3 - DATASET STATISTICS

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df)
print("\nDESCRIBE:")
print(df.describe())
print("\nAVERAGE AGE:")
print(df["Age"].mean())
print("\nAVERAGE MARKS:")
print(df["Marks"].mean())
print("\nHIGHEST MARKS:")
print(df["Marks"].max())
print("\nLOWEST MARKS:")
print(df["Marks"].min())
# Out:
#    StudentID     Name  Age  Marks Department
# 0        101     Arun   21     85        CSE
# 1        102    Priya   22     90         IT
# 2        103    Rahul   20     78        ECE
# 3        104    Divya   21     92        CSE
# 4        105  Karthik   22     88         IT
# 5        106    Meena   20     76        ECE
# 6        107    Vijay   21     95        CSE
# 7        108   Anitha   22     82         IT
# 8        109   Suresh   20     89        ECE
# 9        110  Lakshmi   21     91        CSE
#
# DESCRIBE:
#        StudentID        Age      Marks
# count   10.00000  10.000000  10.000000
# mean   105.50000  21.000000  86.600000
# std      3.02765   0.816497   6.221825
# min    101.00000  20.000000  76.000000
# 25%    103.25000  20.250000  82.750000
# 50%    105.50000  21.000000  88.500000
# 75%    107.75000  21.750000  90.750000
# max    110.00000  22.000000  95.000000
#
# AVERAGE AGE:
# 21.0
#
# AVERAGE MARKS:
# 86.6
#
# HIGHEST MARKS:
# 95
#
# LOWEST MARKS:
# 76

# %% [markdown]
# PROGRAM 4 - MISSING VALUES

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\jeeva\OneDrive\Desktop\Data_Analytics_Learning_Journey\Day-04-Pandas\Reading_CSV_File\Dataset\student.csv")

print(df)
print("\nMISSING VALUES:")
print(df.isnull().sum())
# Out:
#    StudentID     Name  Age  Marks Department
# 0        101     Arun   21     85        CSE
# 1        102    Priya   22     90         IT
# 2        103    Rahul   20     78        ECE
# 3        104    Divya   21     92        CSE
# 4        105  Karthik   22     88         IT
# 5        106    Meena   20     76        ECE
# 6        107    Vijay   21     95        CSE
# 7        108   Anitha   22     82         IT
# 8        109   Suresh   20     89        ECE
# 9        110  Lakshmi   21     91        CSE
#
# MISSING VALUES:
# StudentID     0
# Name          0
# Age           0
# Marks         0
# Department    0
# dtype: int64
