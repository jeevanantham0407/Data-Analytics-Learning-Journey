# %%
import numpy as np

arr = np.random.rand(5)

print(arr)
# Out:
# [0.35392417 0.53749046 0.27389036 0.07387235 0.80132374]

# %%
import numpy as np

arr = np.random.randint(1, 101, 5)

print(arr)
# Out:
# [ 80  35  55 100  11]

# %%
import numpy as np

arr = np.random.randn(5)

print(arr)
# Out:
# [-0.08006825 -0.1346044  -0.37257958 -0.78665209 -0.81767222]

# %%
import numpy as np

departments = np.array(["CSE", "IT", "ECE", "EEE"])

result = np.random.choice(departments, 4)

print(result)
# Out:
# ['IT' 'CSE' 'CSE' 'IT']

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

np.random.shuffle(arr)

print(arr)
# Out:
# [50 20 30 10 40]
