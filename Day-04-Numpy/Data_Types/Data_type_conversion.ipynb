# %%
import numpy as np

arr = np.array([10, 20, 30])

print(arr)
print(arr.dtype)

new_arr = arr.astype(float)

print(new_arr)
print(new_arr.dtype)
# Out:
# [10 20 30]
# int64
# [10. 20. 30.]
# float64
