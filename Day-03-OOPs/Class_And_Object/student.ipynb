# %%
class Student:
    def __init__(self,name,age,marks):
        self.name = name
        self.age = age
        self.marks = marks

    def display_details(self):
        print("Student Name:",self.name)
        print("Student Age:",self.age)
        print("Student Marks:",self.marks)

    def average_calculation(self):
        average = sum(self.marks) / len(self.marks)
        print("Student Average Marks",average)

s1 = Student("Jeevanantham", 21, [85,90,78,88,92])

s1.display_details()
s1.average_calculation()
# Out:
# Student Name: Jeevanantham
# Student Age: 21
# Student Marks: [85, 90, 78, 88, 92]
# Student Average Marks 86.6
