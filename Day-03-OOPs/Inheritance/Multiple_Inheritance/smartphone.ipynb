# %%
class Camera:

    def take_photo(self):
        print("Photo captured successfully.")

    def record_video(self):
        print("Video recording started.")



class MusicPlayer:

    def play_music(self, song):
        print(f"Now Playing: {song}")

    def stop_music(self):
        print("Music stopped.")



class SmartPhone(Camera, MusicPlayer):

    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display_phone(self):
        print("Brand :", self.brand)
        print("Model :", self.model)



phone = SmartPhone("Samsung", "Galaxy S25")

print("------ Phone Details ------")
phone.display_phone()

print("\n------ Camera Features ------")
phone.take_photo()
phone.record_video()

print("\n------ Music Features ------")
phone.play_music("Believer")
phone.stop_music()
# Out:
# ------ Phone Details ------
# Brand : Samsung
# Model : Galaxy S25
#
# ------ Camera Features ------
# Photo captured successfully.
# Video recording started.
#
# ------ Music Features ------
# Now Playing: Believer
# Music stopped.
