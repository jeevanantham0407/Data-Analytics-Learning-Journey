# %%
import requests
from bs4 import BeautifulSoup

url = "https://quotes.toscrape.com/"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

links = soup.find_all("a")

for link in links:
    print("Link Text:", link.text.strip())
    print("URL:", link.get("href"))
    print("-" * 30)
# Out:
# Link Text: Quotes to Scrape
# URL: /
# ------------------------------
# Link Text: Login
# URL: /login
# ------------------------------
# Link Text: (about)
# URL: /author/Albert-Einstein
# ------------------------------
# Link Text: change
# URL: /tag/change/page/1/
# ------------------------------
# Link Text: deep-thoughts
# URL: /tag/deep-thoughts/page/1/
# ------------------------------
# Link Text: thinking
# URL: /tag/thinking/page/1/
# ------------------------------
# Link Text: world
# URL: /tag/world/page/1/
# ------------------------------
# Link Text: (about)
# URL: /author/J-K-Rowling
# ------------------------------
# Link Text: abilities
# URL: /tag/abilities/page/1/
# ------------------------------
# Link Text: choices
# URL: /tag/choices/page/1/
# ------------------------------
# Link Text: (about)
# URL: /author/Albert-Einstein
# ------------------------------
# Link Text: inspirational
# URL: /tag/inspirational/page/1/
# ------------------------------
# Link Text: life
# URL: /tag/life/page/1/
# ------------------------------
# Link Text: live
# URL: /tag/live/page/1/
# ------------------------------
# Link Text: miracle
# URL: /tag/miracle/page/1/
# ------------------------------
# Link Text: miracles
# URL: /tag/miracles/page/1/
# ------------------------------
# Link Text: (about)
# URL: /author/Jane-Austen
# ------------------------------
# Link Text: aliteracy
# URL: /tag/aliteracy/page/1/
# ------------------------------
# Link Text: books
# URL: /tag/books/page/1/
# ------------------------------
# Link Text: classic
# URL: /tag/classic/page/1/
# ------------------------------
# Link Text: humor
# URL: /tag/humor/page/1/
# ------------------------------
# Link Text: (about)
# URL: /author/Marilyn-Monroe
# ------------------------------
# Link Text: be-yourself
# URL: /tag/be-yourself/page/1/
# ------------------------------
# Link Text: inspirational
# URL: /tag/inspirational/page/1/
# ------------------------------
# Link Text: (about)
# URL: /author/Albert-Einstein
# ------------------------------
# Link Text: adulthood
# URL: /tag/adulthood/page/1/
# ------------------------------
# Link Text: success
# URL: /tag/success/page/1/
# ------------------------------
# Link Text: value
# URL: /tag/value/page/1/
# ------------------------------
# Link Text: (about)
# URL: /author/Andre-Gide
# ------------------------------
# Link Text: life
# URL: /tag/life/page/1/
# ------------------------------
# Link Text: love
# URL: /tag/love/page/1/
# ------------------------------
# Link Text: (about)
# URL: /author/Thomas-A-Edison
# ------------------------------
# Link Text: edison
# URL: /tag/edison/page/1/
# ------------------------------
# Link Text: failure
# URL: /tag/failure/page/1/
# ------------------------------
# Link Text: inspirational
# URL: /tag/inspirational/page/1/
# ------------------------------
# Link Text: paraphrased
# URL: /tag/paraphrased/page/1/
# ------------------------------
# Link Text: (about)
# URL: /author/Eleanor-Roosevelt
# ------------------------------
# Link Text: misattributed-eleanor-roosevelt
# URL: /tag/misattributed-eleanor-roosevelt/page/1/
# ------------------------------
# Link Text: (about)
# URL: /author/Steve-Martin
# ------------------------------
# Link Text: humor
# URL: /tag/humor/page/1/
# ------------------------------
# Link Text: obvious
# URL: /tag/obvious/page/1/
# ------------------------------
# Link Text: simile
# URL: /tag/simile/page/1/
# ------------------------------
# Link Text: Next →
# URL: /page/2/
# ------------------------------
# Link Text: love
# URL: /tag/love/
# ------------------------------
# Link Text: inspirational
# URL: /tag/inspirational/
# ------------------------------
# Link Text: life
# URL: /tag/life/
# ------------------------------
# Link Text: humor
# URL: /tag/humor/
# ------------------------------
# Link Text: books
# URL: /tag/books/
# ------------------------------
# Link Text: reading
# URL: /tag/reading/
# ------------------------------
# Link Text: friendship
# URL: /tag/friendship/
# ------------------------------
# Link Text: friends
# URL: /tag/friends/
# ------------------------------
# Link Text: truth
# URL: /tag/truth/
# ------------------------------
# Link Text: simile
# URL: /tag/simile/
# ------------------------------
# Link Text: GoodReads.com
# URL: https://www.goodreads.com/quotes
# ------------------------------
# Link Text: Zyte
# URL: https://www.zyte.com
# ------------------------------
