# %% [markdown]
# HTTP Methods

# %%
methods = {
    "GET": "Retrieve data",
    "POST": "Create data",
    "PUT": "Update data",
    "PATCH": "Partially update data",
    "DELETE": "Delete data"
}

for method, purpose in methods.items():
    print(method, "->", purpose)
# Out:
# GET -> Retrieve data
# POST -> Create data
# PUT -> Update data
# PATCH -> Partially update data
# DELETE -> Delete data
