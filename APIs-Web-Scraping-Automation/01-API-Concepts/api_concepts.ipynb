# %% [markdown]
# API Architecture

# %%
# API Architecture

print("Client")
print("  ↓")
print("API Request")
print("  ↓")
print("Server")
print("  ↓")
print("API Response")
print("  ↓")
print("Client receives data")
# Out:
# Client
#   ↓
# API Request
#   ↓
# Server
#   ↓
# API Response
#   ↓
# Client receives data

# %% [markdown]
# API Components

# %%
print("\nAPI Components")

api = "Application Programming Interface"
client = "Python Program"
server = "Data Server"
endpoint = "/users"
method = "GET"

print("API:", api)
print("Client:", client)
print("Server:", server)
print("Endpoint:", endpoint)
print("HTTP Method:", method)
# Out:
# API Components
# API: Application Programming Interface
# Client: Python Program
# Server: Data Server
# Endpoint: /users
# HTTP Method: GET

# %% [markdown]
# Data Analyst Workflow

# %%
print("\nData Analyst API Workflow")

print("1. Connect to API")
print("2. Send request")
print("3. Receive response")
print("4. Convert JSON data")
print("5. Load data into Pandas")
print("6. Clean data")
print("7. Analyze data")
print("8. Visualize data")
# Out:
# Data Analyst API Workflow
# 1. Connect to API
# 2. Send request
# 3. Receive response
# 4. Convert JSON data
# 5. Load data into Pandas
# 6. Clean data
# 7. Analyze data
# 8. Visualize data
