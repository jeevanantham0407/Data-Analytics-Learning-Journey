# %% [markdown]
# 1.Store And Display Student Details

# %%
name = "Jeevanantham"
age= 23
course= "Data Analytics"
linkedin_URL= "www.linkedin.com/in/jeevanantham0407"
Github_URL= "https://github.com/jeevanantham0407"

print(f"name: {name}")
print(f"age: {age}")
print(f"course: {course}")
print(f"linkedin_URL: {linkedin_URL}")
print(f"Github_URL: {Github_URL}")
# Out:
# name: Jeevanantham
# age: 23
# course: Data Analytics
# linkedin_URL: www.linkedin.com/in/jeevanantham0407
# Github_URL: https://github.com/jeevanantham0407

# %% [markdown]
# 2.Calculate Area Of Rectangle

# %%
width = 10
length = 15

area = length * width

print("Area Of Rectange: ",area)
# Out:
# Area Of Rectange:  150

# %% [markdown]
# 3.Calculate Simple Interest

# %%
principal = 10000
rate = 8
time = 2

simple_interest = (principal * rate * time) / 100

print("Simple Interest:", simple_interest)
# Out:
# Simple Interest: 1600.0

# %% [markdown]
# 4.Convert Celsius to Fahrenheit

# %%
celsius = 28

fahrenheit = (celsius * 9/5) + 32

print("Temperature:", fahrenheit, "°F")
# Out:
# Temperature: 82.4 °F

# %% [markdown]
# 5.Swap Two Variables (Without Temporary Variable)

# %%
a= 10
b= 20

a,b=b,a

print(f"a: {a}")
print(f"b: {b}")
# Out:
# a: 20
# b: 10

# %% [markdown]
# 6.Calculate Total and Average Marks

# %%
math = 90
science = 85
english = 88
python = 95
sql = 92

total = math + science + english + python + sql
average = total / 5

print("Total:", total)
print("Average:", average)
# Out:
# Total: 450
# Average: 90.0

# %% [markdown]
# 7.Calculate Monthly Salary

# %%
basic_salary = 25000
bonus = 3000

total_salary = basic_salary + bonus

print("Monthly Salary:", total_salary)
# Out:
# Monthly Salary: 28000

# %% [markdown]
# 8.Convert Minutes into Hours and Minutes

# %%
minutes = 155

hours = minutes // 60
remaining_minutes = minutes % 60

print(hours, "Hours")
print(remaining_minutes, "Minutes")
# Out:
# 2 Hours
# 35 Minutes

# %% [markdown]
# 9.Calculate Total Price with GST

# %%
price = 1500
gst = 18

gst_amount = (price * gst) / 100
final_price = price + gst_amount

print("Final Price:", final_price)
# Out:
# Final Price: 1770.0

# %% [markdown]
# 10.Calculate Age in Days

# %%
age = 21

days = age * 365

print("Approximate Age in Days:", days)
# Out:
# Approximate Age in Days: 7665
